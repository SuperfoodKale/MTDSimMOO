# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_training, execute_ai_model
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging
import keras
logging.basicConfig(format='%(message)s', level=logging.INFO)

# %%
create_experiment_snapshots([25, 50, 75, 100])
evaluations = []

# %%
# Learning Parameters
epsilon = 1.0  # exploration rate
attacker_sensitivity = 1.0
# Simulator Settings
start_time = 0
finish_time = 3000
mtd_interval = 100
scheme = 'mtd_ai'
total_nodes = 300
new_network = True

# Batch settings
num_iterations = 10
attacker_sensitivity = 1.0

# %%
evaluation = execute_ai_model(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, scheme=scheme, total_nodes=total_nodes, new_network=new_network)
# Out:
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Static period: 0
# Action: 1
# MTD: CompleteTopologyShuffle triggered 0.0s
# Static period: 100.03668327018339
# Action: 3
# MTD: CompleteTopologyShuffle triggered 100.0s
# MTD: Interrupted EXPLOIT_VULN at 120.3s!
# Static period: 79.97935549840565
# Action: 1
# MTD: CompleteTopologyShuffle triggered 200.3s
# Static period: 100.49037624652223
# Action: 1
# MTD: CompleteTopologyShuffle triggered 300.7s
# MTD: Interrupted EXPLOIT_VULN at 320.5s!
# Static period: 81.86853536825595
# Action: 1
# MTD: CompleteTopologyShuffle triggered 402.4s
# Static period: 100.05787007865518
# Action: 2
# MTD: CompleteTopologyShuffle triggered 502.4s
# MTD: Interrupted EXPLOIT_VULN at 523.0s!
# Static period: 79.71270400179526
# Action: 1
# MTD: CompleteTopologyShuffle triggered 602.7s
# Static period: 100.80487008526734
# Action: 3
# MTD: CompleteTopologyShuffle triggered 703.5s
# MTD: Interrupted EXPLOIT_VULN at 724.3s!
# Static period: 79.28632317479764
# Action: 1
# MTD: CompleteTopologyShuffle triggered 803.6s
# Static period: 100.29632567468957
# Action: 4
# MTD: CompleteTopologyShuffle triggered 903.9s
# MTD: Interrupted EXPLOIT_VULN at 924.0s!
# Static period: 81.55732079048244
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1005.5s
# Static period: 100.7420947720716
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1106.3s
# MTD: Interrupted EXPLOIT_VULN at 1127.8s!
# Static period: 78.88088687970185
# Action: 0
# Static period: 78.88088687970185
# Action: 0
# Static period: 78.88088687970185
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1206.7s
# Static period: 100.39246202466484
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1307.1s
# MTD: Interrupted EXPLOIT_VULN at 1328.2s!
# Static period: 79.11704145103727
# Action: 1
# MTD: CompleteTopologyShuffle triggered 1407.3s
# Static period: 100.43790016452681
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1507.7s
# MTD: Interrupted EXPLOIT_VULN at 1528.5s!
# Static period: 80.0666762192036
# Action: 0
# Static period: 80.0666762192036
# Action: 0
# Static period: 80.0666762192036
# Action: 2
# MTD: CompleteTopologyShuffle triggered 1608.5s
# Static period: 100.0982585765903
# Action: 4
# MTD: CompleteTopologyShuffle triggered 1708.6s
# MTD: Interrupted ENUM_HOST at 1729.5s!
# Static period: 79.298553315052
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1808.8s
# Static period: 101.34126579741292
# Action: 0
# Static period: 101.34126579741292
# Action: 0
# Static period: 101.34126579741292
# Action: 3
# MTD: CompleteTopologyShuffle triggered 1910.2s
# MTD: Interrupted EXPLOIT_VULN at 1929.3s!
# Static period: 80.98166549931557
# Action: 0
# Static period: 80.98166549931557
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2010.2s
# Static period: 100.24784680884864
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2110.5s
# MTD: Interrupted EXPLOIT_VULN at 2130.9s!
# Static period: 80.04927124615051
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2210.9s
# Static period: 100.41016708234793
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2311.3s
# MTD: Interrupted ENUM_HOST at 2331.2s!
# Static period: 80.13301672744183
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2411.4s
# Static period: 100.05089386972895
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2511.4s
# MTD: Interrupted SCAN_PORT at 2531.6s!
# Static period: 80.44315928471633
# Action: 4
# MTD: CompleteTopologyShuffle triggered 2612.0s
# Static period: 100.47934361833495
# Action: 2
# MTD: CompleteTopologyShuffle triggered 2712.5s
# MTD: Interrupted EXPLOIT_VULN at 2732.9s!
# Static period: 80.4465213824451
# Action: 3
# MTD: CompleteTopologyShuffle triggered 2813.4s
# Static period: 100.24616265069199
# Action: 1
# MTD: CompleteTopologyShuffle triggered 2913.6s
# MTD: Interrupted EXPLOIT_VULN at 2934.0s!

# %%
evaluation.visualise_mtd_operation()

# %%
evaluation._security_metric_record
# Out:
#     host_compromise_ratio  exposed_endpoints  attack_path_exposure_score  \
# 0                0.000000                5.0                    0.241245
# 1                0.000000                5.0                    0.248173
# 2                0.003333                5.0                    0.244372
# 3                0.003333                5.0                    0.249251
# 4                0.003333                5.0                    0.241410
# 5                0.006667                5.0                    0.242114
# 6                0.006667                5.0                    0.252193
# 7                0.006667                5.0                    0.256566
# 8                0.006667                5.0                    0.250635
# 9                0.006667                5.0                    0.250475
# 10               0.006667                5.0                    0.585345
# 11               0.006667                5.0                    0.588793
# 12               0.006667                5.0                    0.238516
# 13               0.006667                5.0                    0.238516
# 14               0.006667                5.0                    0.238516
# 15               0.010000                5.0                    0.242176
# 16               0.010000                5.0                    0.817143
# 17               0.010000                5.0                    0.813810
# 18               0.010000                5.0                    0.215460
# 19               0.010000                5.0                    0.215460
# 20               0.010000                5.0                    0.215460
# 21               0.010000                5.0                    0.213952
# 22               0.016667                5.0                    0.247931
# 23               0.020000                5.0                    0.252552
# 24               0.020000                5.0                    0.252552
# 25               0.020000                5.0                    0.252552
# 26               0.020000                5.0                    0.249697
# 27               0.020000                5.0                    0.249697
# 28               0.020000                5.0                    0.256437
# 29               0.020000                5.0                    0.235577
# 30               0.023333                5.0                    0.233328
# 31               0.026667                5.0                    0.477007
# 32               0.030000                5.0                    0.477007
# 33               0.030000                5.0                    0.253206
# 34               0.030000                5.0                    0.255587
# 35               0.033333                5.0                    0.253378
# 36               0.036667                5.0                    0.249267
#
#     overall_asr_ratio       roa  shortest_path_vulnerability      risk  \
# 0            0.000000  0.000000                     0.000000  0.000000
# 1            0.000000  0.000000                     0.000000  0.000000
# 2            0.000000  0.092977                     0.000000  0.223987
# 3            0.000000  0.092977                     0.000000  0.223987
# 4            0.000000  0.092977                     0.000000  0.223987
# 5            0.000000  0.624093                     0.000000  1.944824
# 6            0.000000  0.624093                     0.000000  1.944824
# 7            0.000000  0.624093                     0.000000  1.944824
# 8            0.000000  0.624093                     0.000000  1.944824
# 9            0.000000  0.624093                     0.000000  1.944824
# 10           0.000000  0.624093                   -54.200000  1.944824
# 11           0.000000  0.624093                   -54.200000  1.944824
# 12           0.000000  0.624093                    45.166667  1.944824
# 13           0.000000  0.624093                    45.166667  1.944824
# 14           0.000000  0.624093                    45.166667  1.944824
# 15           0.272727  1.612581                    45.166667  3.253348
# 16           0.250000  1.612581                   -38.571429  3.253348
# 17           0.230769  1.612581                   -38.571429  3.253348
# 18           0.214286  1.612581                    33.750000  3.253348
# 19           0.214286  1.612581                    33.750000  3.253348
# 20           0.214286  1.612581                    33.750000  3.253348
# 21           0.214286  1.612581                    33.750000  3.253348
# 22           0.214286  0.753323                     0.000000  3.053692
# 23           0.294643  0.476930                     0.000000  2.019584
# 24           0.294643  0.476930                     0.000000  2.019584
# 25           0.294643  0.476930                     0.000000  2.019584
# 26           0.273810  0.476930                     0.000000  2.019584
# 27           0.273810  0.476930                     0.000000  2.019584
# 28           0.273810  0.476930                     0.000000  2.019584
# 29           0.265038  0.476930                     0.000000  2.019584
# 30           0.265038  0.280408                     0.000000  1.253826
# 31           0.265038  3.840384                   -16.500000  5.967340
# 32           0.319549  0.795190                   -16.500000  3.287022
# 33           0.307127  0.795190                    15.230769  3.287022
# 34           0.307127  0.795190                    15.230769  3.287022
# 35           0.301692  1.042065                     0.000000  2.644232
# 36           0.301692  3.238992                     0.000000  6.932194
#
#     mtd_frequency  overall_mtcc_avg  time_since_last_mtd        times
# 0        0.000000          0.000000             0.000000     0.000000
# 1        0.000000          0.000000           100.036683   100.036683
# 2        0.008314          0.000000            79.979355   200.258316
# 3        0.008314          0.000000           100.490376   300.748692
# 4        0.006240          0.000000            81.868535   402.381241
# 5        0.006240          0.000000           100.057870   502.439111
# 6        0.005736          0.000000            79.712704   602.690233
# 7        0.005736          0.000000           100.804870   703.495103
# 8        0.005523          0.000000            79.286323   803.560863
# 9        0.005523          0.000000           100.296326   903.857189
# 10       0.005411          0.000000            81.557321  1005.539039
# 11       0.005411          0.000000           100.742095  1106.281133
# 12       0.005320          0.000000            78.880887  1206.681564
# 13       0.005320          0.000000            78.880887  1206.681564
# 14       0.005320          0.000000            78.880887  1206.681564
# 15       0.005320       1070.428476           100.392462  1307.074026
# 16       0.005270       1146.554912            79.117041  1407.302122
# 17       0.005270       1236.132978           100.437900  1507.740022
# 18       0.005234       1312.726448            80.066676  1608.537796
# 19       0.005234       1312.726448            80.066676  1608.537796
# 20       0.005234       1312.726448            80.066676  1608.537796
# 21       0.005234       1408.181657           100.098259  1708.636055
# 22       0.005204       1429.644768            79.298553  1808.828121
# 23       0.005204       1485.933936           101.341266  1910.169387
# 24       0.005204       1485.933936           101.341266  1910.169387
# 25       0.005204       1485.933936           101.341266  1910.169387
# 26       0.005183       1517.743254            80.981665  2010.235887
# 27       0.005183       1517.743254            80.981665  2010.235887
# 28       0.005183       1574.247657           100.247847  2110.483733
# 29       0.005162       1608.417876            80.049271  2210.913800
# 30       0.005162       1613.118405           100.410167  2311.323967
# 31       0.005148       1613.118405            80.133017  2411.359232
# 32       0.005148       1749.795723           100.050894  2511.410126
# 33       0.005135       1771.097940            80.443159  2612.036331
# 34       0.005135       1804.225137           100.479344  2712.515675
# 35       0.005123       1824.936467            80.446521  2813.376085
# 36       0.005123       1824.936467           100.246163  2913.622248

# %%
evaluation.visualize_host_compromise_ratio()

# %%
evaluation.visualize_attack_path_exposure_score()

# %%
evaluation.visualize_risk()

# %%
# evaluation = execute_ai_model(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, scheme=scheme, total_nodes=total_nodes, new_network=new_network)

# %%
for i in range(num_iterations):
    evaluation = execute_ai_model(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, scheme=scheme, total_nodes=total_nodes, 
                                  new_network=new_network, attacker_sensitivity=attacker_sensitivity, model_path='AI_model/models_joo_kai/main_network_parameter_set_6.h5')
    evaluations.append(evaluation._security_metric_record)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 for i in range(num_iterations):
# ----> 2     evaluation = execute_ai_model(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, scheme=scheme, total_nodes=total_nodes,
#       3                                   new_network=new_network, attacker_sensitivity=attacker_sensitivity, model_path='AI_model/main_network_parameter_set_6.h5')
#       4     evaluations.append(evaluation._security_metric_record)
#
# File c:\Users\Joo_Kai\Documents\GitHub\MTDSim\experiments\run.py:521, in execute_ai_model(start_time, finish_time, scheme, mtd_interval, custom_strategies, checkpoints, total_nodes, total_endpoints, total_subnets, total_layers, target_layer, total_database, terminate_compromise_ratio, new_network, epsilon, attacker_sensitivity, model_path)
#     510 custom_objects = {'mse': mse}
#     513 # try:
#     514 #     main_network = legacy_h5_format.load_model_from_hdf5(f"AI_model/{model}.h5", custom_objects=custom_objects)  #For Mac
#     515 #     print("On Mac")
#    (...)
#     518 #     main_network = load_model(model_path, custom_objects=custom_objects)    #For Windows/Linux
#     519 #     print("On Windows/Linux")
# --> 521 main_network = load_model(model_path, custom_objects=custom_objects)
#     522 main_network.compile(loss=MeanSquaredError(), optimizer=Adam())
#     524 security_metrics_record = SecurityMetricStatistics()
#
# File c:\Users\Joo_Kai\anaconda3\envs\mtdsim\Lib\site-packages\keras\src\saving\saving_api.py:238, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     230     return saving_lib.load_model(
#     231         filepath,
#     232         custom_objects=custom_objects,
#     233         compile=compile,
#     234         safe_mode=safe_mode,
#     235     )
#     237 # Legacy case.
# --> 238 return legacy_sm_saving_lib.load_model(
#     239     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     240 )
#
# File c:\Users\Joo_Kai\anaconda3\envs\mtdsim\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Joo_Kai\anaconda3\envs\mtdsim\Lib\site-packages\keras\src\saving\legacy\save.py:234, in load_model(filepath, custom_objects, compile, options)
#     232 if isinstance(filepath_str, str):
#     233     if not tf.io.gfile.exists(filepath_str):
# --> 234         raise IOError(
#     235             f"No file or directory found at {filepath_str}"
#     236         )
#     238     if tf.io.gfile.isdir(filepath_str):
#     239         return saved_model_load.load(
#     240             filepath_str, compile, options
#     241         )
#
# OSError: No file or directory found at AI_model/main_network_parameter_set_6.h5

# %%
visualize_metric_ratio(evaluations, 'host_compromise_ratio')

# %%
visualize_metric_ratio(evaluations, 'risk')

# %%
visualize_metric_ratio(evaluations, 'attack_path_exposure_score')

# %%
evaluations = []
attacker_sensitivity = 0.5
for i in range(num_iterations):
    evaluation = execute_ai_model(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, scheme=scheme, total_nodes=total_nodes, 
                                  new_network=new_network, attacker_sensitivity=attacker_sensitivity, model_path='AI_model/main_network_mtd_ai_attacker_small_1.h5')
    evaluations.append(evaluation._security_metric_record)
# Out:
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
visualize_metric_ratio(evaluations, 'host_compromise_ratio')

# %%
visualize_metric_ratio(evaluations, 'risk')

# %%
visualize_metric_ratio(evaluations, 'attack_path_exposure_score')

# %%
evaluations = []
attacker_sensitivity = 0.1
for i in range(num_iterations):
    evaluation = execute_ai_model(start_time=start_time, finish_time=finish_time, mtd_interval=mtd_interval, scheme=scheme, total_nodes=total_nodes, 
                                  new_network=new_network, attacker_sensitivity=attacker_sensitivity, model_path='AI_model/main_network_mtd_ai_attacker_small_1.h5')
    evaluations.append(evaluation._security_metric_record)
# Out:
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
visualize_metric_ratio(evaluations, 'host_compromise_ratio')

# %%
visualize_metric_ratio(evaluations, 'risk')

# %%
visualize_metric_ratio(evaluations, 'attack_path_exposure_score')
