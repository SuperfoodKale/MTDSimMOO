# %%
import os
import sys
current_directory = os.getcwd()
if not os.path.exists(current_directory + '\\experimental_data'):
    os.makedirs(current_directory + '\\experimental_data')
    os.makedirs(current_directory + '\\experimental_data\\plots')
    os.makedirs(current_directory + '\\experimental_data\\results')
sys.path.append(current_directory.replace('experiments', ''))
import warnings
import matplotlib.pyplot as plt
# warnings.filterwarnings("ignore")
plt.set_loglevel('WARNING')
from run import execute_simulation, create_experiment_snapshots, execute_ai_model, single_mtd_simulation, mtd_ai_simulation, multiple_mtd_simulation, specific_multiple_mtd_simulation
from mtdnetwork.mtd.completetopologyshuffle import CompleteTopologyShuffle
from mtdnetwork.mtd.ipshuffle import IPShuffle
from mtdnetwork.mtd.hosttopologyshuffle import HostTopologyShuffle
from mtdnetwork.mtd.portshuffle import PortShuffle
from mtdnetwork.mtd.osdiversity import OSDiversity
from mtdnetwork.mtd.servicediversity import ServiceDiversity
from mtdnetwork.mtd.usershuffle import UserShuffle
from mtdnetwork.mtd.osdiversityassignment import OSDiversityAssignment
import logging
import pandas as pd
import numpy as np
from math import pi
import matplotlib.pyplot as plt
import matplotlib.cm as cm

logging.basicConfig(format='%(message)s', level=logging.INFO)

# import absl.logging
# absl.logging.set_verbosity(absl.logging.FATAL)

import concurrent.futures
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       8 sys.path.append(current_directory.replace('experiments', ''))
#       9 import warnings
# ---> 10 import matplotlib.pyplot as plt
#      11 # warnings.filterwarnings("ignore")
#      12 plt.set_loglevel('WARNING')
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\matplotlib\__init__.py:169
#     166 import tempfile
#     167 import warnings
# --> 169 import numpy
#     170 from packaging.version import parse as parse_version
#     172 # cbook must import matplotlib only within function
#     173 # definitions, so it is safe to import from it here.
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\__init__.py:223
#     221 from .core import round, abs, max, min
#     222 # now that numpy modules are imported, can initialize limits
# --> 223 core.getlimits._register_known_types()
#     225 __all__.extend(['__version__', 'show_config'])
#     226 __all__.extend(core.__all__)
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\getlimits.py:226, in _register_known_types()
#     224 with numeric.errstate(all='ignore'):
#     225     huge_f128 = (ld(1) - epsneg_f128) / tiny_f128 * ld(4)
# --> 226 float128_ma = MachArLike(ld,
#     227                          machep=-112,
#     228                          negep=-113,
#     229                          minexp=-16382,
#     230                          maxexp=16384,
#     231                          it=112,
#     232                          iexp=15,
#     233                          ibeta=2,
#     234                          irnd=5,
#     235                          ngrd=0,
#     236                          eps=exp2(ld(-112)),
#     237                          epsneg=epsneg_f128,
#     238                          huge=huge_f128,
#     239                          tiny=tiny_f128)
#     240 # IEEE 754 128-bit binary float
#     241 _register_type(float128_ma,
#     242     b'\x9a\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\xfb\xbf')
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\getlimits.py:55, in MachArLike.__init__(self, ftype, eps, epsneg, huge, tiny, ibeta, smallest_subnormal, **kwargs)
#      52 self.precision = int(-log10(self.eps))
#      53 self.resolution = self._float_to_float(
#      54     self._float_conv(10) ** (-self.precision))
# ---> 55 self._str_eps = self._float_to_str(self.eps)
#      56 self._str_epsneg = self._float_to_str(self.epsneg)
#      57 self._str_xmin = self._float_to_str(self.xmin)
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\getlimits.py:119, in MachArLike._float_to_str(self, value)
#     111 def _float_to_str(self, value):
#     112     """Converts float to str.
#     113
#     114     Parameters
#    (...)
#     117         value to be converted.
#     118     """
# --> 119     return self.params['fmt'] % array(_fr0(value)[0], self.ftype)
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\arrayprint.py:1586, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1579 # the str of 0d arrays is a special case: It should appear like a scalar,
#    1580 # so floats are not truncated by `precision`, and strings are not wrapped
#    1581 # in quotes. So we return the str of the scalar value.
#    1582 if a.shape == ():
#    1583     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1584     # for which indexing with () returns a 0d instead of a scalar by using
#    1585     # ndarray's getindex. Also guard against recursive 0d object arrays.
# -> 1586     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
#    1588 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# AttributeError: module 'numpy' has no attribute 'ndarray'

# %%
# Learning Parameters
epsilon = 1.0  # exploration rate

# Simulator Settings
start_time = 0
finish_time = 15000
mtd_interval = [200]
network_size = [150]
total_nodes = 150
new_network = True

trial = 100

mtd_strategies = [
    CompleteTopologyShuffle,
    # HostTopologyShuffle,
    IPShuffle,
    OSDiversity,
    # PortShuffle,
    # OSDiversityAssignment,
    ServiceDiversity,
    # UserShuffle
]

result_head_path = ''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      10 new_network = True
#      12 trial = 100
#      14 mtd_strategies = [
# ---> 15     CompleteTopologyShuffle,
#      16     # HostTopologyShuffle,
#      17     IPShuffle,
#      18     OSDiversity,
#      19     # PortShuffle,
#      20     # OSDiversityAssignment,
#      21     ServiceDiversity,
#      22     # UserShuffle
#      23 ]
#      25 result_head_path = ''
#
# NameError: name 'CompleteTopologyShuffle' is not defined

# %%
class Experiment:
    def __init__(self, epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network, model, trial, result_head_path, file_name=None, attacker_sensitivity=1):
        # Learning Parameters
        self.epsilon = epsilon  # exploration rate

        # Simulator Settings
        self.start_time = start_time
        self.finish_time = finish_time
        self.schemes = [ 'mtd_ai', 'simultaneous', 'random', 'alternative']
        self.total_nodes = total_nodes
        self.new_network = new_network
        self.model = model
        self.trial = trial
        self.model_path = f"AI_model/MostRecentModels/main_network_{model}.h5"
        self.mtd_strategies = [
            CompleteTopologyShuffle,
            # HostTopologyShuffle,
            IPShuffle,
            OSDiversity,
            # PortShuffle,
            # OSDiversityAssignment,
            ServiceDiversity,
            # UserShuffle
        ]
        self.mtd_interval = mtd_interval
        self.network_size = network_size
        self.result_head_path = result_head_path
        self.attacker_sensitivity = attacker_sensitivity

        if file_name is not None:
            self.file_name = file_name
        else:
            self.file_name = self.model


    def run_trials(self, scheme):
        with concurrent.futures.ProcessPoolExecutor() as executor:
            futures = []

            for i in range(self.trial):
                if i % 10 == 0:
                    print("Trial_", i)

                if scheme == 'nomtd':
                    # mtd = single_mtd_simulation("nomtd", [None], 
                    #                                             mtd_interval=self.mtd_interval,network_size=self.network_size) 
                    futures.append(executor.submit(single_mtd_simulation, "nomtd", [None], 
                                                                mtd_interval=self.mtd_interval,network_size=self.network_size))
                elif scheme == 'mtd_ai':
                    # try:
                    #     mtd = mtd_ai_simulation(self.model, self.model_path, start_time, finish_time, total_nodes, new_network = new_network, 
                    #                                              mtd_interval=self.mtd_interval,network_size=self.network_size )  
                    # except:
                    #     continue
                    # mtd = mtd_ai_simulation(self.file_name, self.model_path, start_time, finish_time, total_nodes, new_network = new_network, 
                    #                             mtd_interval=self.mtd_interval,network_size=self.network_size, attacker_sensitivity=self.attacker_sensitivity)
                    futures.append(executor.submit(mtd_ai_simulation, self.file_name, self.model_path, start_time, finish_time, total_nodes, 
                                           new_network, self.mtd_interval, self.network_size, self.attacker_sensitivity))    
                else:
                    futures.append(executor.submit(specific_multiple_mtd_simulation, scheme, self.mtd_strategies, scheme, mtd_interval=self.mtd_interval,network_size=self.network_size))
                    # mtd = specific_multiple_mtd_simulation(scheme, self.mtd_strategies, scheme, mtd_interval=self.mtd_interval,network_size=self.network_size)

    
    def get_result(self, path, scheme, folder_path = f'experimental_data/results'):
        csv_path = f'{folder_path}/{path}.csv'
        df = pd.read_csv(csv_path)
        return df
    
    def get_result_checkpoint_median(self, scheme, data, checkpoints = 9):
        df = self.get_result(data, scheme).drop('Name', axis = 1)
        df['group'] = df.index // checkpoints
        # Group by the new column and calculate median
        df = df.groupby('group').median().reset_index(drop=True)
        # Drop the 'group' column if you don't need it in the result
        df = df.drop(columns='group', errors='ignore')
        return df

    def get_result_stats(self, checkpoint_medians,stats_type = 'median'):
        if stats_type == 'median':
            return checkpoint_medians.median()
        return checkpoint_medians.std()
    
    def raw_result_stats_pipeline(self, scheme, data, run_trial = False, stats_type = 'median', checkpoints = 9):
        if run_trial:
            self.run_trials(scheme)
        checkpoint_medians = self.get_result_checkpoint_median(scheme, data, checkpoints)
        result = self.get_result_stats(checkpoint_medians, stats_type = stats_type)
        return result
        
    def scale_metrics(self, metrics_dict, normalization_dict):
        # Define which metrics should be maximized and which should be minimized
        metrics_to_maximize = {"time_to_compromise"}  
        metrics_to_minimize = {'host_compromise_ratio', 'attack_path_exposure', 'ASR', 'ROA', 'exposed_endpoints', "risk"}  

        scaled_metrics = {}

        for key, value in metrics_dict.items():
            if key in normalization_dict:
                norm_value = normalization_dict[key]

                if norm_value != 0:
                    if key in metrics_to_maximize:
                        # Normalize by dividing the metric value by the normalization value
                        scaled_metrics[key] = value / norm_value
                    elif key in metrics_to_minimize:
                        # Inverse the ratio for metrics to be minimized
                        scaled_metrics[key] = norm_value / value
                    else:
                        # Handle cases where the metric is not in either category
                        scaled_metrics[key] = value / norm_value
                else:
                    # Handle the case where norm_value is zero
                    scaled_metrics[key] = 1  # Or any other placeholder value as needed
            else:
                # Handle cases where normalization value is not defined
                scaled_metrics[key] = value  # Or handle differently as needed
        return scaled_metrics

    def scaled_pipeline(self, scheme, data, run_trial = False, stats_type = 'median'):
        nomtd_result = self.raw_result_stats_pipeline('nomtd', 'nomtd', run_trial, stats_type)
        scheme_result = self.raw_result_stats_pipeline(scheme, data, run_trial, stats_type)
        scaled_scheme_result = self.scale_metrics(scheme_result.to_dict(), nomtd_result.to_dict())
        return {scheme:scaled_scheme_result}
    
    def multiple_scaled_pipeline(self, schemes, data_name, run_trial = False, stats_type = 'median'):
        multi_schemes = {}
        nomtd_result = self.raw_result_stats_pipeline('nomtd', 'nomtd', run_trial, stats_type)
        for scheme, data in zip(schemes, data_name):
            scheme_result = self.raw_result_stats_pipeline(scheme, data, run_trial, stats_type)
            scaled_scheme_result = self.scale_metrics(scheme_result.to_dict(), nomtd_result.to_dict())

            multi_schemes[scheme] = scaled_scheme_result
        return multi_schemes

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch

class RadarPlot(Experiment):
    def __init__(self, epsilon, start_time, finish_time, mtd_interval, network_size, total_nodes, new_network, model, trial, result_head_path):
        super().__init__(epsilon, start_time, finish_time, mtd_interval, network_size, total_nodes, new_network, model, trial, result_head_path)

    def calculate_area(self, values):
        """
        Calculate the area of the radar chart plot using the Shoelace theorem.
        """
        # Ensure that the polygon is closed by repeating the first value at the end
        values = np.array(values)
        x = values * np.cos(np.linspace(0, 2 * np.pi, len(values), endpoint=False))
        y = values * np.sin(np.linspace(0, 2 * np.pi, len(values), endpoint=False))
        
        # Calculate area using Shoelace theorem
        area = 0.5 * np.abs(np.dot(x, np.roll(y, 1)) - np.dot(y, np.roll(x, 1)))
        
        return area

    def plot_n_schemes(self, schemes_data, show_labels=True):
        """
        Plots multiple schemes on a radar chart with a maximum cap of 100 on the values and specific metrics removed, using pastel colors.
        
        :param schemes_data: A dictionary where keys are scheme names and values are dictionaries of metrics.
        :param show_labels: Boolean to determine whether or not to display the score labels on the polygons.
        """
        # Metrics to exclude from the plot
        metrics_to_exclude = {'network_size', 'exposed_endpoints', 'mtd_interval', 'MEF', 'shortest_path_variability', 'host_compromise_ratio'}

        # Mapping of current metric names to their display labels
        metric_labels_mapping = {
            'attack_path_exposure': 'Attack Path Exposure',
            'time_to_compromise': 'Time to Compromise',
            'ROA': 'ROA',
            'ASR': 'ASR',
            'risk': 'Risk'
        }

        scheme_names = list(schemes_data.keys())
        first_scheme = schemes_data[scheme_names[0]]

        # Filter out excluded metrics and apply label mapping
        labels = [metric_labels_mapping.get(label, label) for label in first_scheme.keys() if label not in metrics_to_exclude]
        num_vars = len(labels)

        # Compute angle for each axis
        angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
        angles += angles[:1]  # Complete the circle

        fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

        # Use pastel colormap for colors
        colors = plt.cm.Pastel1.colors
        legend_patches = []

        # Keep track of areas for legend
        areas = []

        for i, scheme_name in enumerate(scheme_names):
            metrics_values = schemes_data[scheme_name]
            
            # Filter out values corresponding to excluded metrics
            filtered_values = {k: v for k, v in metrics_values.items() if k not in metrics_to_exclude}
            
            # Cap the values at 100
            values = np.array(list(filtered_values.values()))
            values = np.minimum(values, 100)  # Cap the values at 100
            
            # Close the circle by appending the first value again
            closed_values = values.tolist()
            closed_values += closed_values[:1]  # Close the circle

            # Calculate area of the scheme's radar plot using only the original values, not the closed circle
            area = self.calculate_area(values)
            areas.append(area)  # Store area for later use in the legend

            # Plot data with pastel colors
            ax.fill(angles, closed_values, color=colors[i % len(colors)], alpha=0.5)
            ax.plot(angles, closed_values, color=colors[i % len(colors)], linewidth=2, label=f'{scheme_name} (Area: {area:.2f})')

            # Add score labels if show_labels is True
            if show_labels:
                for j in range(num_vars):
                    angle = angles[j]
                    value = closed_values[j]
                    ax.text(angle, value + 0.05, f'{value:.2f}', horizontalalignment='center', size=10, color='black')

        # Add labels
        ax.set_yticklabels([])
        ax.set_xticks(angles[:-1])
        ax.set_xticklabels(labels, rotation=45, ha='right')

        # Create legend using pre-calculated areas
        legend_patches = [Patch(color=colors[i % len(colors)], label=f'{scheme_names[i]} (Area: {areas[i]:.2f})') for i in range(len(scheme_names))]
        plt.legend(handles=legend_patches, loc='upper right', bbox_to_anchor=(1.1, 1.1))

        plt.show()

# %%
def plot_metrics_grid(data_sets, metrics):
    if len(metrics) != 5:
        print("Please provide exactly 5 metrics.")
        return
    
    # Create a 2x3 grid of subplots (2 rows, 3 columns)
    fig, axs = plt.subplots(2, 3, figsize=(15, 10))
    
    # Define pastel colors for the bars
    pastel_colors = ['#FFB3BA', '#FFDFBA', '#FFFFBA', '#BAFFC9', '#BAE1FF']
    
    # Flatten the axes array for easy iteration
    axs = axs.flatten()
    
    # Plot each metric in a separate subplot
    for i, metric in enumerate(metrics):
        metric_values = []
        for j, parameter_set in enumerate(data_sets):
            try:
                value = parameter_set['mtdai'][metric]
                metric_values.append(value)
            except KeyError:
                print(f"Metric '{metric}' not found in parameter_set_{j+1}")
                metric_values.append(None)
        
        # Update labels to remove 'parameter_' prefix
        labels = [f'set_{k+1}' for k in range(len(data_sets))]
        colors = pastel_colors[:len(data_sets)]
        
        # Create the bar plot for the current metric
        bars = axs[i].bar(labels, metric_values, color=colors)
        
        # Set the title, labels, and rotate the x-axis labels
        axs[i].set_title(f'{metric}')
        axs[i].set_xlabel('Parameter Set')
        axs[i].set_ylabel(f'{metric}')
        axs[i].tick_params(axis='x', rotation=45)
        
        # Add labels on top of each bar
        for bar in bars:
            yval = bar.get_height()
            axs[i].text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), 
                        ha='center', va='bottom')
    
    # Hide the unused 6th subplot if only plotting 5 metrics
    axs[5].axis('off')
    
    # Adjust layout
    plt.tight_layout()
    
    # Display the plot
    plt.show()

# %%
def create_stacked_bar_chart(schemes_data, show_totals=True, length=8, width=6, sort_order='none'):
    # Metrics to exclude from the plot
    metrics_to_exclude = {'network_size', 'exposed_endpoints', 'mtd_interval', 'MEF', 'shortest_path_variability', 'host_compromise_ratio'}

    # Mapping of current metric names to their display labels
    metric_labels_mapping = {
        'attack_path_exposure': 'Attack Path Exposure',
        'time_to_compromise': 'Time to Compromise',
        'ROA': 'ROA',
        'ASR': 'ASR',
        'risk': 'Risk'
    }

    # Extract parameter names (keys) and values for each parameter set, excluding the metrics in `metrics_to_exclude`
    parameter_sets = list(schemes_data.keys())
    parameters = [p for p in schemes_data[parameter_sets[0]].keys() if p not in metrics_to_exclude]

    # Map parameters to their display names
    display_parameters = [metric_labels_mapping[p] for p in parameters]

    # Prepare the data for plotting
    parameter_values = np.array([[schemes_data[ps][p] for p in parameters] for ps in parameter_sets])

    # Sort the data based on the chosen order
    if sort_order == 'asc':
        # Sort parameter_sets based on the total values in ascending order
        total_values = parameter_values.sum(axis=1)
        sorted_indices = np.argsort(total_values)
        parameter_sets = [parameter_sets[i] for i in sorted_indices]
        parameter_values = parameter_values[sorted_indices]
    elif sort_order == 'desc':
        # Sort parameter_sets based on the total values in descending order
        total_values = parameter_values.sum(axis=1)
        sorted_indices = np.argsort(-total_values)
        parameter_sets = [parameter_sets[i] for i in sorted_indices]
        parameter_values = parameter_values[sorted_indices]

    # Set the pastel color map
    pastel_colors = cm.get_cmap('Pastel1', len(display_parameters))

    # Create figure and axis
    fig, ax = plt.subplots(figsize=(length, width))

    # Plot the bars and add value labels
    for i, parameter in enumerate(display_parameters[:-1]):  # Keep original pastel colors for all but the last parameter
        bars = ax.bar(parameter_sets, parameter_values[:, i], label=parameter, color=pastel_colors(i), 
                      bottom=parameter_values[:, :i].sum(axis=1))

        # Add value labels in the middle of each segment
        for bar in bars:
            height = bar.get_height()
            bottom = bar.get_y()
            ax.text(bar.get_x() + bar.get_width() / 2, bottom + height / 2, f'{height:.2f}', ha='center', va='center', fontsize=8)

    # Use a darker color for the top-most segment (only change this one)
    top_color = '#ff6666'  # You can adjust this to your preference
    bars = ax.bar(parameter_sets, parameter_values[:, -1], label=display_parameters[-1], color=top_color,
                  bottom=parameter_values[:, :-1].sum(axis=1))

    # Add value labels in the middle of the top-most segment
    for bar in bars:
        height = bar.get_height()
        bottom = bar.get_y()
        ax.text(bar.get_x() + bar.get_width() / 2, bottom + height / 2, f'{height:.2f}', ha='center', va='center', fontsize=8)

    # Add total values on top of each bar
    if show_totals:
        total_values = parameter_values.sum(axis=1)
        for idx, rect in enumerate(ax.patches[:len(parameter_sets)]):
            ax.text(rect.get_x() + rect.get_width() / 2, total_values[idx] + 0.05, f'{total_values[idx]:.2f}', 
                    ha='center', va='bottom', fontsize=10, fontweight='bold')

    # Add labels and title
    ax.set_ylabel('Values')
    # ax.set_title('Stacked Bar Chart with Values and Totals')

    # Rotate x-axis labels for better readability
    plt.xticks(rotation=45, ha='right')

    # Adjust layout to ensure everything fits
    plt.tight_layout()

    # Show plot
    plt.show()

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
from collections import defaultdict
import os

METRICS_MAXIMIZE = {"time_to_compromise"}
METRICS_MINIMIZE = {'host_compromise_ratio', 'attack_path_exposure', 'ASR', 'ROA', 'exposed_endpoints', "risk"}
METRICS_EXCLUDE = {
    'network_size', 'exposed_endpoints', 'mtd_interval', 'MEF',
    'shortest_path_variability', 'host_compromise_ratio'
}
METRICS_TO_COMPARE = ['risk', 'ROA', 'attack_path_exposure', 'time_to_compromise', 'ASR']

def tost_ind(a, b, low_eqbound, high_eqbound, alpha=0.05):
    mean_a = np.mean(a)
    mean_b = np.mean(b)
    se_a = np.std(a, ddof=1) / np.sqrt(len(a))
    se_b = np.std(b, ddof=1) / np.sqrt(len(b))

    t_low = (mean_a - mean_b - low_eqbound) / np.sqrt(se_a**2 + se_b**2)
    t_high = (mean_a - mean_b - high_eqbound) / np.sqrt(se_a**2 + se_b**2)

    p_low = stats.t.cdf(t_low, df=min(len(a), len(b)) - 1)
    p_high = 1 - stats.t.cdf(t_high, df=min(len(a), len(b)) - 1)

    is_equivalent = (p_low > alpha) and (p_high > alpha)

    return p_low, p_high, is_equivalent

def load_checkpoint_medians(file_path, checkpoints=9):
    try:
        df = pd.read_csv(file_path)
        df = df.drop(columns='Name', errors='ignore')
        df['group'] = df.index // checkpoints
        grouped = df.groupby('group').median().reset_index(drop=True)
        return grouped
    except Exception as e:
        print(f"Failed to read {file_path}: {e}")
        return None

def normalize_to_baseline(metric_values, baseline_values, metric_name):
    normalized = []
    for val, base in zip(metric_values, baseline_values):
        if val == 0 or base == 0:
            continue
        if metric_name in METRICS_MAXIMIZE:
            normalized.append(val / base)
        elif metric_name in METRICS_MINIMIZE:
            normalized.append(base / val)
        else:
            normalized.append(val / base)
    return normalized

def compare_all_files(filenames, folder_a="experimental_data/original_results", folder_b="experimental_data/results", baseline_file='nomtd', checkpoints=9):
    results = defaultdict(dict)

    baseline_df = load_checkpoint_medians(os.path.join(folder_a, f"{baseline_file}.csv"), checkpoints)
    if baseline_df is None:
        raise ValueError("Baseline file missing or unreadable.")

    for file in filenames:
        path_a = os.path.join(folder_a, f"{file}.csv")
        path_b = os.path.join(folder_b, f"{file}.csv")

        data_a = load_checkpoint_medians(path_a, checkpoints)
        data_b = load_checkpoint_medians(path_b, checkpoints)

        if data_a is None or data_b is None:
            print(f"Skipping {file} due to missing data.")
            continue

        for metric in METRICS_TO_COMPARE:
            if metric in METRICS_EXCLUDE or metric not in data_a.columns or metric not in data_b.columns:
                continue

            try:
                a_values = normalize_to_baseline(data_a[metric].values, baseline_df[metric].values, metric)
                b_values = normalize_to_baseline(data_b[metric].values, baseline_df[metric].values, metric)

                if len(a_values) < 5 or len(b_values) < 5:
                    continue

                # Perform t-test
                t_stat, p_ttest = stats.ttest_ind(a_values, b_values, equal_var=False)

                # Perform Mann-Whitney U test
                u_stat, p_mwu = stats.mannwhitneyu(a_values, b_values, alternative='two-sided')

                # Perform TOST
                low_eqbound = -0.1  
                high_eqbound = 0.1  
                p_low, p_high, is_equivalent = tost_ind(a_values, b_values, low_eqbound, high_eqbound)

                # Store results
                results[file][metric] = {
                    't_test_p': p_ttest,
                    'mwu_p': p_mwu,
                    'p_low': p_low,
                    'p_high': p_high,
                    'is_equivalent': is_equivalent,
                    'mean_A': np.mean(a_values),
                    'mean_B': np.mean(b_values)
                }

            except Exception as e:
                print(f"Error processing {file} - {metric}: {e}")
                continue

    return results

def print_results(results, alpha=0.05):
    for file, metrics in results.items():
        print(f"\nResults for file: {file}")
        print("  Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result")
        print("  ----------------------|------------|------------|-------------|------------|------------|------------|------------------")

        similar_count = 0

        for metric, vals in metrics.items():
            mean_a = vals['mean_A']
            mean_b = vals['mean_B']
            p_t = vals['t_test_p']
            p_u = vals['mwu_p']
            p_low = vals['p_low']
            p_high = vals['p_high']
            is_equivalent = vals['is_equivalent']

            is_similar = (p_t > alpha) and (p_u > alpha) and is_equivalent
            result = "✅ Similar" if is_similar else "❌ Different"
            if is_similar:
                similar_count += 1

            print(f"  {metric:<22} |  {mean_a:<10.3f} |  {mean_b:<10.3f} |  {p_t:<10.4f} |  {p_u:<10.4f} |  {p_low:<10.4f} |  {p_high:<10.4f} | {result}")

        # File-level summary
        overall = "✅ OVERALL SIMILAR" if similar_count >= 3 else "❌ OVERALL DIFFERENT"
        print(f"\n  Summary: {similar_count}/5 metrics similar → {overall}")

# %%
files = [
    "gamma_0.5", "gamma_0.6", "gamma_0.7", "gamma_0.75", "gamma_0.8", "gamma_0.85", "gamma_0.9", "gamma_0.95", "gamma_0.98", "gamma_0.99",
    "epsilon_0.5_decay_0.98", "epsilon_0.5_decay_0.99", "epsilon_0.5_decay_0.995", "epsilon_0.5_decay_0.998",
    "epsilon_0.6_decay_0.98", "epsilon_0.6_decay_0.99", "epsilon_0.6_decay_0.995", "epsilon_0.6_decay_0.998",
    "epsilon_0.7_decay_0.98", "epsilon_0.7_decay_0.99", "epsilon_0.7_decay_0.995", "epsilon_0.7_decay_0.998",
    "epsilon_0.8_decay_0.98", "epsilon_0.8_decay_0.99", "epsilon_0.8_decay_0.995", "epsilon_0.8_decay_0.998",
    "epsilon_0.9_decay_0.98", "epsilon_0.9_decay_0.99", "epsilon_0.9_decay_0.995", "epsilon_0.9_decay_0.998",
    "epsilon_1.0_decay_0.98", "epsilon_1.0_decay_0.99", "epsilon_1.0_decay_0.995", "epsilon_1.0_decay_0.998",
    "train_start_500", "train_start_1000", "train_start_1500", "train_start_2000", "nomtd"
]

results = compare_all_files(files)
print_results(results)
# Out:
# Results for file: gamma_0.5
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.247      |  11.698     |  0.0860     |  0.3074     |  0.0459     |  0.9576     | ❌ Different
#   ROA                    |  4.827      |  11.889     |  0.2141     |  0.1717     |  0.1126     |  0.8937     | ✅ Similar
#   attack_path_exposure   |  3.280      |  4.154      |  0.0276     |  0.0261     |  0.0271     |  0.9912     | ❌ Different
#   time_to_compromise     |  2.049      |  1.974      |  0.5151     |  0.5564     |  0.9311     |  0.5864     | ✅ Similar
#   ASR                    |  1.771      |  1.685      |  0.2208     |  0.2225     |  0.9938     |  0.5808     | ✅ Similar
#
#   Summary: 3/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.6
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.427      |  2.136      |  0.3818     |  0.3870     |  0.8247     |  0.2116     | ✅ Similar
#   ROA                    |  2.935      |  1.811      |  0.3768     |  0.2193     |  0.8304     |  0.2114     | ✅ Similar
#   attack_path_exposure   |  3.831      |  4.104      |  0.4625     |  0.6436     |  0.3213     |  0.8398     | ✅ Similar
#   time_to_compromise     |  1.958      |  1.922      |  0.7719     |  0.7424     |  0.8591     |  0.6950     | ✅ Similar
#   ASR                    |  1.767      |  1.717      |  0.4440     |  0.4620     |  0.9855     |  0.7757     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.7
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.006      |  10.090     |  0.1183     |  0.2758     |  0.0615     |  0.9428     | ✅ Similar
#   ROA                    |  1.702      |  16.296     |  0.0845     |  0.1945     |  0.0433     |  0.9587     | ❌ Different
#   attack_path_exposure   |  3.650      |  4.056      |  0.3923     |  0.2193     |  0.2607     |  0.8539     | ✅ Similar
#   time_to_compromise     |  1.985      |  1.977      |  0.9540     |  0.9586     |  0.7820     |  0.7472     | ✅ Similar
#   ASR                    |  1.707      |  1.688      |  0.7603     |  0.6904     |  0.9666     |  0.8975     | ✅ Similar
#
#   Summary: 4/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.75
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  11.825     |  15.278     |  0.7731     |  0.6404     |  0.3903     |  0.6160     | ✅ Similar
#   ROA                    |  4.201      |  16.007     |  0.2044     |  0.8086     |  0.1044     |  0.8993     | ✅ Similar
#   attack_path_exposure   |  3.775      |  3.827      |  0.8550     |  0.6971     |  0.5671     |  0.7024     | ✅ Similar
#   time_to_compromise     |  1.884      |  2.104      |  0.0682     |  0.0593     |  0.1590     |  0.9941     | ✅ Similar
#   ASR                    |  1.644      |  1.765      |  0.0801     |  0.0199     |  0.3808     |  0.9985     | ❌ Different
#
#   Summary: 4/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.8
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.425      |  7.907      |  0.4266     |  0.9724     |  0.2176     |  0.7907     | ✅ Similar
#   ROA                    |  2.262      |  11.307     |  0.3763     |  0.9862     |  0.1908     |  0.8144     | ✅ Similar
#   attack_path_exposure   |  3.630      |  3.829      |  0.5411     |  0.6159     |  0.3810     |  0.8182     | ✅ Similar
#   time_to_compromise     |  2.044      |  2.061      |  0.8948     |  0.9311     |  0.7372     |  0.8142     | ✅ Similar
#   ASR                    |  1.742      |  1.766      |  0.7253     |  0.7163     |  0.8629     |  0.9601     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.85
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  4.082      |  1.891      |  0.1187     |  0.2758     |  0.9473     |  0.0690     | ✅ Similar
#   ROA                    |  5.214      |  2.114      |  0.1364     |  0.2129     |  0.9368     |  0.0754     | ✅ Similar
#   attack_path_exposure   |  4.138      |  3.910      |  0.5594     |  0.3546     |  0.7969     |  0.3717     | ✅ Similar
#   time_to_compromise     |  2.046      |  1.945      |  0.3660     |  0.2066     |  0.9592     |  0.4952     | ✅ Similar
#   ASR                    |  1.729      |  1.697      |  0.6678     |  0.6465     |  0.9579     |  0.8202     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.9
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.836      |  5.777      |  0.2154     |  0.4465     |  0.1164     |  0.8988     | ✅ Similar
#   ROA                    |  2.837      |  7.208      |  0.1673     |  0.6281     |  0.0890     |  0.9203     | ✅ Similar
#   attack_path_exposure   |  3.908      |  3.928      |  0.9587     |  0.8086     |  0.5802     |  0.6200     | ✅ Similar
#   time_to_compromise     |  2.075      |  1.991      |  0.5064     |  0.5799     |  0.9222     |  0.5490     | ✅ Similar
#   ASR                    |  1.707      |  1.744      |  0.5451     |  0.4160     |  0.8441     |  0.9834     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.95
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.649      |  1.623      |  0.3931     |  0.5918     |  0.8248     |  0.2206     | ✅ Similar
#   ROA                    |  3.171      |  1.810      |  0.3296     |  0.2758     |  0.8515     |  0.1834     | ✅ Similar
#   attack_path_exposure   |  3.757      |  3.820      |  0.8479     |  0.8288     |  0.5443     |  0.6886     | ✅ Similar
#   time_to_compromise     |  2.066      |  2.008      |  0.6315     |  0.4889     |  0.8986     |  0.6323     | ✅ Similar
#   ASR                    |  1.761      |  1.709      |  0.4322     |  0.7358     |  0.9857     |  0.7654     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  1.442      |  1.141      |  0.3964     |  0.5109     |  0.8677     |  0.2863     | ✅ Similar
#   ROA                    |  1.491      |  1.086      |  0.3775     |  0.4781     |  0.8619     |  0.2539     | ✅ Similar
#   attack_path_exposure   |  3.777      |  4.449      |  0.0198     |  0.0202     |  0.0256     |  0.9947     | ❌ Different
#   time_to_compromise     |  1.981      |  1.901      |  0.4860     |  0.5799     |  0.9375     |  0.5712     | ✅ Similar
#   ASR                    |  1.762      |  1.686      |  0.2635     |  0.5108     |  0.9927     |  0.6374     | ✅ Similar
#
#   Summary: 4/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: gamma_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.396      |  4.725      |  0.5930     |  0.3241     |  0.3113     |  0.7163     | ✅ Similar
#   ROA                    |  4.994      |  3.822      |  0.6338     |  0.8221     |  0.6966     |  0.3322     | ✅ Similar
#   attack_path_exposure   |  3.979      |  3.924      |  0.8892     |  0.8762     |  0.6528     |  0.5462     | ✅ Similar
#   time_to_compromise     |  1.987      |  1.985      |  0.9852     |  0.8899     |  0.7845     |  0.7737     | ✅ Similar
#   ASR                    |  1.695      |  1.702      |  0.9219     |  1.0000     |  0.9004     |  0.9290     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.5_decay_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  1.899      |  29.163     |  0.2189     |  0.0900     |  0.1103     |  0.8914     | ✅ Similar
#   ROA                    |  1.692      |  16.848     |  0.1475     |  0.0748     |  0.0750     |  0.9275     | ✅ Similar
#   attack_path_exposure   |  3.705      |  3.950      |  0.4855     |  0.6971     |  0.3407     |  0.8347     | ✅ Similar
#   time_to_compromise     |  2.025      |  1.994      |  0.8264     |  0.9311     |  0.8223     |  0.6893     | ✅ Similar
#   ASR                    |  1.760      |  1.776      |  0.8113     |  0.9724     |  0.8819     |  0.9488     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.5_decay_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.382      |  2.264      |  0.3215     |  0.6529     |  0.8575     |  0.1849     | ✅ Similar
#   ROA                    |  3.688      |  2.694      |  0.4931     |  0.6281     |  0.7729     |  0.2700     | ✅ Similar
#   attack_path_exposure   |  3.700      |  4.216      |  0.1690     |  0.3141     |  0.1348     |  0.9465     | ✅ Similar
#   time_to_compromise     |  2.038      |  1.895      |  0.2594     |  0.2758     |  0.9683     |  0.3669     | ✅ Similar
#   ASR                    |  1.742      |  1.686      |  0.4115     |  0.5217     |  0.9856     |  0.7416     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.5_decay_0.995
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.210      |  18.688     |  0.2112     |  0.8763     |  0.1071     |  0.8957     | ✅ Similar
#   ROA                    |  3.967      |  16.621     |  0.3359     |  0.4781     |  0.1700     |  0.8338     | ✅ Similar
#   attack_path_exposure   |  3.672      |  3.941      |  0.3919     |  0.3457     |  0.2959     |  0.8764     | ✅ Similar
#   time_to_compromise     |  2.098      |  2.008      |  0.4956     |  0.3870     |  0.9198     |  0.5286     | ✅ Similar
#   ASR                    |  1.778      |  1.736      |  0.5777     |  0.7225     |  0.9660     |  0.7797     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.5_decay_0.998
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.576      |  2.377      |  0.8474     |  0.5109     |  0.6131     |  0.4618     | ✅ Similar
#   ROA                    |  4.169      |  2.747      |  0.4754     |  0.6529     |  0.7763     |  0.2544     | ✅ Similar
#   attack_path_exposure   |  3.482      |  3.867      |  0.2463     |  0.4182     |  0.1968     |  0.9241     | ✅ Similar
#   time_to_compromise     |  2.008      |  2.029      |  0.8681     |  0.8899     |  0.7343     |  0.8291     | ✅ Similar
#   ASR                    |  1.722      |  1.727      |  0.9450     |  0.9931     |  0.8990     |  0.9202     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.6_decay_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.625      |  1.564      |  0.1901     |  0.1772     |  0.9214     |  0.1194     | ✅ Similar
#   ROA                    |  2.510      |  1.794      |  0.3740     |  0.2682     |  0.8420     |  0.2236     | ✅ Similar
#   attack_path_exposure   |  3.628      |  3.756      |  0.7132     |  0.6717     |  0.4682     |  0.7421     | ✅ Similar
#   time_to_compromise     |  2.074      |  1.916      |  0.2026     |  0.1003     |  0.9776     |  0.3203     | ✅ Similar
#   ASR                    |  1.773      |  1.683      |  0.2345     |  0.0733     |  0.9915     |  0.5554     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.6_decay_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.652      |  5.758      |  0.5813     |  0.5799     |  0.3005     |  0.7172     | ✅ Similar
#   ROA                    |  3.317      |  5.961      |  0.4338     |  0.9036     |  0.2266     |  0.7906     | ✅ Similar
#   attack_path_exposure   |  3.836      |  3.952      |  0.7205     |  0.7896     |  0.4810     |  0.7460     | ✅ Similar
#   time_to_compromise     |  1.971      |  1.973      |  0.9886     |  0.9173     |  0.7853     |  0.7933     | ✅ Similar
#   ASR                    |  1.700      |  1.696      |  0.9580     |  0.9724     |  0.9346     |  0.9211     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.6_decay_0.995
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  6.249      |  3.161      |  0.3950     |  0.7687     |  0.8093     |  0.2058     | ✅ Similar
#   ROA                    |  4.774      |  3.986      |  0.7822     |  0.9586     |  0.6217     |  0.4051     | ✅ Similar
#   attack_path_exposure   |  3.273      |  4.087      |  0.0085     |  0.0077     |  0.0119     |  0.9975     | ❌ Different
#   time_to_compromise     |  2.103      |  1.899      |  0.0926     |  0.1236     |  0.9916     |  0.1957     | ✅ Similar
#   ASR                    |  1.778      |  1.688      |  0.1434     |  0.1437     |  0.9979     |  0.5643     | ✅ Similar
#
#   Summary: 4/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.6_decay_0.998
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  5.987      |  2.764      |  0.1327     |  0.1828     |  0.9377     |  0.0739     | ✅ Similar
#   ROA                    |  6.516      |  3.033      |  0.1414     |  0.2259     |  0.9327     |  0.0784     | ✅ Similar
#   attack_path_exposure   |  3.712      |  3.714      |  0.9963     |  0.9586     |  0.6468     |  0.6502     | ✅ Similar
#   time_to_compromise     |  2.004      |  1.980      |  0.8540     |  0.6907     |  0.8280     |  0.7212     | ✅ Similar
#   ASR                    |  1.717      |  1.709      |  0.9023     |  0.7620     |  0.9554     |  0.9295     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.7_decay_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  1.726      |  2.960      |  0.1723     |  0.1154     |  0.1066     |  0.9273     | ✅ Similar
#   ROA                    |  2.087      |  3.332      |  0.1594     |  0.1003     |  0.1001     |  0.9327     | ✅ Similar
#   attack_path_exposure   |  3.702      |  4.089      |  0.2326     |  0.3366     |  0.1891     |  0.9298     | ✅ Similar
#   time_to_compromise     |  2.051      |  2.116      |  0.6300     |  0.6529     |  0.6032     |  0.8858     | ✅ Similar
#   ASR                    |  1.772      |  1.801      |  0.7187     |  0.9242     |  0.8043     |  0.9387     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.7_decay_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.451      |  4.359      |  0.3417     |  0.5564     |  0.1846     |  0.8403     | ✅ Similar
#   ROA                    |  2.598      |  5.117      |  0.3244     |  0.7424     |  0.1731     |  0.8457     | ✅ Similar
#   attack_path_exposure   |  3.786      |  3.979      |  0.4334     |  0.5751     |  0.3534     |  0.8792     | ✅ Similar
#   time_to_compromise     |  2.045      |  2.061      |  0.8952     |  0.7293     |  0.7503     |  0.8245     | ✅ Similar
#   ASR                    |  1.774      |  1.757      |  0.8134     |  1.0000     |  0.9436     |  0.8729     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.7_decay_0.995
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  4.925      |  2.475      |  0.4578     |  0.9586     |  0.7795     |  0.2386     | ✅ Similar
#   ROA                    |  3.268      |  2.514      |  0.6768     |  0.7035     |  0.6807     |  0.3595     | ✅ Similar
#   attack_path_exposure   |  3.553      |  3.861      |  0.2873     |  0.2897     |  0.2371     |  0.9166     | ✅ Similar
#   time_to_compromise     |  2.024      |  2.035      |  0.9331     |  0.9311     |  0.7472     |  0.7968     | ✅ Similar
#   ASR                    |  1.743      |  1.769      |  0.7032     |  0.8354     |  0.8598     |  0.9635     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.7_decay_0.998
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.150      |  1.846      |  0.1362     |  0.4063     |  0.9428     |  0.0866     | ✅ Similar
#   ROA                    |  2.850      |  2.227      |  0.5023     |  0.3870     |  0.7800     |  0.2878     | ✅ Similar
#   attack_path_exposure   |  3.421      |  3.857      |  0.1287     |  0.1445     |  0.1220     |  0.9658     | ✅ Similar
#   time_to_compromise     |  1.996      |  1.986      |  0.9280     |  0.9862     |  0.8373     |  0.7904     | ✅ Similar
#   ASR                    |  1.759      |  1.802      |  0.5868     |  0.6219     |  0.7658     |  0.9606     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.8_decay_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.743      |  4.130      |  0.8597     |  0.4999     |  0.4481     |  0.5876     | ✅ Similar
#   ROA                    |  3.893      |  4.005      |  0.9637     |  0.3776     |  0.4981     |  0.5343     | ✅ Similar
#   attack_path_exposure   |  3.727      |  3.935      |  0.4865     |  0.6591     |  0.3593     |  0.8455     | ✅ Similar
#   time_to_compromise     |  2.008      |  1.960      |  0.6956     |  0.7035     |  0.8818     |  0.6629     | ✅ Similar
#   ASR                    |  1.721      |  1.703      |  0.7506     |  0.7163     |  0.9740     |  0.9129     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.8_decay_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  5.604      |  1.587      |  0.2328     |  0.2535     |  0.8891     |  0.1222     | ✅ Similar
#   ROA                    |  7.780      |  1.777      |  0.1953     |  0.1154     |  0.9058     |  0.1014     | ✅ Similar
#   attack_path_exposure   |  4.213      |  3.799      |  0.2950     |  0.9724     |  0.9003     |  0.2141     | ✅ Similar
#   time_to_compromise     |  2.043      |  2.002      |  0.7364     |  0.6529     |  0.8731     |  0.6860     | ✅ Similar
#   ASR                    |  1.767      |  1.729      |  0.6115     |  0.3368     |  0.9640     |  0.7993     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.8_decay_0.995
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.324      |  2.761      |  0.7223     |  0.2835     |  0.3925     |  0.6679     | ✅ Similar
#   ROA                    |  2.008      |  1.933      |  0.9006     |  0.7035     |  0.6141     |  0.5166     | ✅ Similar
#   attack_path_exposure   |  3.938      |  3.908      |  0.9312     |  0.6971     |  0.6471     |  0.5816     | ✅ Similar
#   time_to_compromise     |  1.978      |  1.995      |  0.8960     |  0.9448     |  0.7492     |  0.8231     | ✅ Similar
#   ASR                    |  1.717      |  1.715      |  0.9757     |  0.9104     |  0.9618     |  0.9570     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.8_decay_0.998
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  3.532      |  1.658      |  0.1782     |  0.3074     |  0.9206     |  0.1019     | ✅ Similar
#   ROA                    |  2.742      |  2.058      |  0.4821     |  0.3683     |  0.7878     |  0.2753     | ✅ Similar
#   attack_path_exposure   |  3.869      |  3.849      |  0.9526     |  0.5103     |  0.6411     |  0.5961     | ✅ Similar
#   time_to_compromise     |  2.037      |  2.006      |  0.8098     |  0.7164     |  0.8448     |  0.7067     | ✅ Similar
#   ASR                    |  1.729      |  1.715      |  0.8650     |  0.9173     |  0.9202     |  0.8606     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.9_decay_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  1.305      |  2.223      |  0.1732     |  0.5799     |  0.1126     |  0.9330     | ✅ Similar
#   ROA                    |  1.482      |  1.850      |  0.4984     |  0.7687     |  0.3116     |  0.8038     | ✅ Similar
#   attack_path_exposure   |  3.789      |  3.963      |  0.5685     |  0.6220     |  0.4046     |  0.8129     | ✅ Similar
#   time_to_compromise     |  2.126      |  1.998      |  0.3129     |  0.3414     |  0.9595     |  0.4125     | ✅ Similar
#   ASR                    |  1.821      |  1.774      |  0.5175     |  0.4516     |  0.9738     |  0.7639     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.9_decay_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.436      |  3.355      |  0.6181     |  0.6529     |  0.3290     |  0.7090     | ✅ Similar
#   ROA                    |  2.370      |  2.918      |  0.7398     |  0.9586     |  0.3933     |  0.6521     | ✅ Similar
#   attack_path_exposure   |  3.799      |  3.636      |  0.6018     |  0.9724     |  0.7977     |  0.4202     | ✅ Similar
#   time_to_compromise     |  1.987      |  1.990      |  0.9831     |  0.9311     |  0.7964     |  0.8079     | ✅ Similar
#   ASR                    |  1.729      |  1.739      |  0.8939     |  0.9724     |  0.8938     |  0.9330     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.9_decay_0.995
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  1.690      |  1.966      |  0.6690     |  0.4889     |  0.3930     |  0.7185     | ✅ Similar
#   ROA                    |  1.897      |  2.278      |  0.6658     |  0.2129     |  0.3755     |  0.7062     | ✅ Similar
#   attack_path_exposure   |  3.920      |  3.907      |  0.9770     |  0.3456     |  0.5989     |  0.5766     | ✅ Similar
#   time_to_compromise     |  2.020      |  2.053      |  0.8001     |  0.8627     |  0.6955     |  0.8430     | ✅ Similar
#   ASR                    |  1.689      |  1.725      |  0.5972     |  0.9242     |  0.8244     |  0.9728     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_0.9_decay_0.998
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.815      |  6.929      |  0.1941     |  0.5564     |  0.1030     |  0.9075     | ✅ Similar
#   ROA                    |  2.996      |  7.638      |  0.3045     |  0.6907     |  0.1579     |  0.8524     | ✅ Similar
#   attack_path_exposure   |  4.108      |  3.430      |  0.0337     |  0.0240     |  0.9906     |  0.0371     | ❌ Different
#   time_to_compromise     |  1.939      |  1.941      |  0.9847     |  0.9036     |  0.8191     |  0.8287     | ✅ Similar
#   ASR                    |  1.692      |  1.680      |  0.8562     |  0.4159     |  0.9515     |  0.9069     | ✅ Similar
#
#   Summary: 4/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_1.0_decay_0.98
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.698      |  1.480      |  0.3588     |  0.7819     |  0.8389     |  0.1999     | ✅ Similar
#   ROA                    |  2.650      |  1.264      |  0.1394     |  0.5681     |  0.9425     |  0.0850     | ✅ Similar
#   attack_path_exposure   |  3.739      |  3.800      |  0.8574     |  0.6220     |  0.5460     |  0.6817     | ✅ Similar
#   time_to_compromise     |  2.053      |  1.989      |  0.6035     |  0.9862     |  0.9031     |  0.6123     | ✅ Similar
#   ASR                    |  1.717      |  1.699      |  0.7421     |  0.7227     |  0.9795     |  0.9256     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_1.0_decay_0.99
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.117      |  3.076      |  0.6035     |  0.9586     |  0.3212     |  0.7162     | ✅ Similar
#   ROA                    |  2.931      |  2.545      |  0.8173     |  0.8086     |  0.6139     |  0.4323     | ✅ Similar
#   attack_path_exposure   |  3.759      |  3.959      |  0.5403     |  0.5109     |  0.3801     |  0.8182     | ✅ Similar
#   time_to_compromise     |  2.055      |  2.099      |  0.7401     |  0.4999     |  0.6629     |  0.8576     | ✅ Similar
#   ASR                    |  1.733      |  1.762      |  0.6956     |  0.9793     |  0.8376     |  0.9575     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_1.0_decay_0.995
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  8.213      |  4.821      |  0.5974     |  0.7555     |  0.7061     |  0.3046     | ✅ Similar
#   ROA                    |  10.078     |  3.346      |  0.3752     |  0.7952     |  0.8157     |  0.1913     | ✅ Similar
#   attack_path_exposure   |  3.666      |  3.726      |  0.8530     |  0.8938     |  0.5487     |  0.6880     | ✅ Similar
#   time_to_compromise     |  2.094      |  1.982      |  0.3211     |  0.3326     |  0.9657     |  0.4591     | ✅ Similar
#   ASR                    |  1.747      |  1.717      |  0.6778     |  0.7293     |  0.9594     |  0.8317     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: epsilon_1.0_decay_0.998
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  13.803     |  2.130      |  0.3403     |  0.8491     |  0.8318     |  0.1722     | ✅ Similar
#   ROA                    |  13.610     |  2.404      |  0.3460     |  0.7555     |  0.8291     |  0.1751     | ✅ Similar
#   attack_path_exposure   |  3.725      |  3.851      |  0.7299     |  0.7035     |  0.4715     |  0.7304     | ✅ Similar
#   time_to_compromise     |  2.033      |  1.961      |  0.5928     |  0.7035     |  0.8959     |  0.5839     | ✅ Similar
#   ASR                    |  1.741      |  1.776      |  0.6715     |  0.7686     |  0.7820     |  0.9439     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: train_start_500
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.330      |  1.959      |  0.6985     |  0.6907     |  0.6875     |  0.3891     | ✅ Similar
#   ROA                    |  2.459      |  1.927      |  0.5919     |  1.0000     |  0.7366     |  0.3323     | ✅ Similar
#   attack_path_exposure   |  3.836      |  3.835      |  0.9965     |  0.8899     |  0.6111     |  0.6078     | ✅ Similar
#   time_to_compromise     |  2.000      |  1.954      |  0.7167     |  0.9036     |  0.8711     |  0.6635     | ✅ Similar
#   ASR                    |  1.708      |  1.721      |  0.8381     |  0.9517     |  0.9108     |  0.9578     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: train_start_1000
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  6.278      |  1.509      |  0.2805     |  0.9862     |  0.8645     |  0.1453     | ✅ Similar
#   ROA                    |  11.864     |  1.055      |  0.2886     |  0.4999     |  0.8578     |  0.1465     | ✅ Similar
#   attack_path_exposure   |  3.999      |  3.712      |  0.3597     |  0.2360     |  0.8882     |  0.2759     | ✅ Similar
#   time_to_compromise     |  1.938      |  2.061      |  0.2829     |  0.2394     |  0.4203     |  0.9700     | ✅ Similar
#   ASR                    |  1.721      |  1.733      |  0.8598     |  0.7357     |  0.8870     |  0.9387     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: train_start_1500
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.422      |  11.926     |  0.3567     |  0.6780     |  0.1809     |  0.8241     | ✅ Similar
#   ROA                    |  2.404      |  19.220     |  0.3469     |  0.6529     |  0.1749     |  0.8279     | ✅ Similar
#   attack_path_exposure   |  3.769      |  4.147      |  0.3326     |  0.3797     |  0.2392     |  0.8862     | ✅ Similar
#   time_to_compromise     |  2.033      |  1.957      |  0.5518     |  0.6654     |  0.9110     |  0.5731     | ✅ Similar
#   ASR                    |  1.771      |  1.724      |  0.5400     |  0.5109     |  0.9686     |  0.7581     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: train_start_2000
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  2.449      |  2.729      |  0.8213     |  0.9311     |  0.4425     |  0.6199     | ✅ Similar
#   ROA                    |  2.340      |  2.150      |  0.7968     |  0.7424     |  0.6519     |  0.4516     | ✅ Similar
#   attack_path_exposure   |  3.704      |  3.787      |  0.7747     |  0.6907     |  0.5233     |  0.7343     | ✅ Similar
#   time_to_compromise     |  1.950      |  1.974      |  0.8281     |  0.9862     |  0.7444     |  0.8599     | ✅ Similar
#   ASR                    |  1.715      |  1.773      |  0.4570     |  0.6590     |  0.6998     |  0.9736     | ✅ Similar
#
#   Summary: 5/5 metrics similar → ✅ OVERALL SIMILAR
#
# Results for file: nomtd
#   Metric                 |   Mean A   |   Mean B   |   t-test p  |   MWU p    |   p_low    |   p_high   | Result
#   ----------------------|------------|------------|-------------|------------|------------|------------|------------------
#   risk                   |  1.000      |  1.027      |  0.8732     |  0.0821     |  0.6686     |  0.7740     | ✅ Similar
#   ROA                    |  1.000      |  0.988      |  0.9319     |  0.2153     |  0.7788     |  0.7256     | ✅ Similar
#   attack_path_exposure   |  1.000      |  1.459      |  0.0000     |  0.0000     |  0.0000     |  1.0000     | ❌ Different
#   time_to_compromise     |  1.000      |  1.253      |  0.0000     |  0.0000     |  0.0002     |  1.0000     | ❌ Different
#   ASR                    |  1.000      |  0.857      |  0.0000     |  0.0000     |  1.0000     |  0.0086     | ❌ Different
#
#   Summary: 2/5 metrics similar → ❌ OVERALL DIFFERENT
# C:\Users\Bubbakins\anaconda3\envs\mtdsimdebugtest\Lib\site-packages\scipy\stats\_axis_nan_policy.py:523: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#cell to run all experiments and verify and validate results
import tensorflow as tf
gamma_vals = [0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.98, 0.99]
ids_sensitivity = [1]
epsilons = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
epsilon_decays = [0.980, 0.990, 0.995, 0.998]
train_starts = [500, 1000, 1500, 2000]
tf.config.set_visible_devices([], 'GPU')

ResultFileNames = []


for gamma in gamma_vals:
    mod = f"gamma_{gamma}"
    ResultFileNames.append(mod)
    print(f"Running experiments for model {mod}")
    result = Experiment(epsilon=epsilon, 
                    start_time=start_time, 
                    finish_time=finish_time, 
                    mtd_interval=mtd_interval, 
                    network_size=network_size,
                    total_nodes=total_nodes, 
                    new_network=new_network, 
                    model=mod, 
                    trial=trial, 
                    result_head_path=result_head_path, 
                    file_name=mod, 
                    attacker_sensitivity=1)
    result.run_trials('mtd_ai')

for epsilon in epsilons:
    for decay in epsilon_decays:
        mod = f"epsilon_{epsilon}_decay_{decay}"
        ResultFileNames.append(mod)
        print(f"Running experiments for model {mod}")
        result = Experiment(epsilon=epsilon, 
                        start_time=start_time, 
                        finish_time=finish_time, 
                        mtd_interval=mtd_interval, 
                        network_size=network_size,
                        total_nodes=total_nodes, 
                        new_network=new_network, 
                        model=mod, 
                        trial=trial, 
                        result_head_path=result_head_path, 
                        file_name=mod, 
                        attacker_sensitivity=1)
        result.run_trials('mtd_ai')

for start in train_starts:
    mod = f"train_start_{start}"
    ResultFileNames.append(mod)
    print(f"Running experiments for model {mod}")
    result = Experiment(epsilon=epsilon, 
                    start_time=start_time, 
                    finish_time=finish_time, 
                    mtd_interval=mtd_interval, 
                    network_size=network_size,
                    total_nodes=total_nodes, 
                    new_network=new_network, 
                    model=mod, 
                    trial=trial, 
                    result_head_path=result_head_path, 
                    file_name=mod, 
                    attacker_sensitivity=1)
    result.run_trials('mtd_ai')

models = ['nomtd']
# models = ['parameter_set_1']
ids_sensitivity = [1]

models = ['nomtd']
for model in models:
    for sensitivity in ids_sensitivity:
        file_name = f"{model}_{sensitivity}"
        ResultFileNames.append(file_name)
        print(f"Running experiments for model {model}")
        result = Experiment(epsilon=epsilon, 
                            start_time=start_time, 
                            finish_time=finish_time, 
                            mtd_interval=mtd_interval, 
                            network_size=network_size,
                            total_nodes=total_nodes, 
                            new_network=new_network, 
                            model=model, 
                            trial=trial, 
                            result_head_path=result_head_path, 
                            file_name=file_name, 
                            attacker_sensitivity=sensitivity)
        result.run_trials('nomtd')


files = [
    "gamma_0.5", "gamma_0.6", "gamma_0.7", "gamma_0.75", "gamma_0.8", "gamma_0.85", "gamma_0.9", "gamma_0.95", "gamma_0.98", "gamma_0.99",
    "epsilon_0.5_decay_0.98", "epsilon_0.5_decay_0.99", "epsilon_0.5_decay_0.995", "epsilon_0.5_decay_0.998",
    "epsilon_0.6_decay_0.98", "epsilon_0.6_decay_0.99", "epsilon_0.6_decay_0.995", "epsilon_0.6_decay_0.998",
    "epsilon_0.7_decay_0.98", "epsilon_0.7_decay_0.99", "epsilon_0.7_decay_0.995", "epsilon_0.7_decay_0.998",
    "epsilon_0.8_decay_0.98", "epsilon_0.8_decay_0.99", "epsilon_0.8_decay_0.995", "epsilon_0.8_decay_0.998",
    "epsilon_0.9_decay_0.98", "epsilon_0.9_decay_0.99", "epsilon_0.9_decay_0.995", "epsilon_0.9_decay_0.998",
    "epsilon_1.0_decay_0.98", "epsilon_1.0_decay_0.99", "epsilon_1.0_decay_0.995", "epsilon_1.0_decay_0.998",
    "train_start_500", "train_start_1000", "train_start_1500", "train_start_2000", "nomtd"
]

results = compare_all_files(files)
print_results(results)
# Out:
# Running experiments for model gamma_0.5
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.6
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.7
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.75
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.8
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.85
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.9
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.95
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.98
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model gamma_0.99
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.5_decay_0.98
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.5_decay_0.99
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.5_decay_0.995
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.5_decay_0.998
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.6_decay_0.98
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.6_decay_0.99
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.6_decay_0.995
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.6_decay_0.998
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.7_decay_0.98
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.7_decay_0.99
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.7_decay_0.995
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.7_decay_0.998
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# Running experiments for model epsilon_0.8_decay_0.98
# Trial_ 0
# Trial_ 10
# Trial_ 20
# Trial_ 30
# Trial_ 40
# Trial_ 50
# Trial_ 60
# Trial_ 70
# Trial_ 80
# Trial_ 90
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 48
#      35         print(f"Running experiments for model {mod}")
#      36         result = Experiment(epsilon=epsilon,
#      37                         start_time=start_time,
#      38                         finish_time=finish_time,
#    (...)
#      46                         file_name=mod,
#      47                         attacker_sensitivity=1)
# ---> 48         result.run_trials('mtd_ai')
#      50 for start in train_starts:
#      51     mod = f"train_start_{start}"
#
# Cell In[3], line 37, in Experiment.run_trials(self, scheme)
#      36 def run_trials(self, scheme):
# ---> 37     with concurrent.futures.ProcessPoolExecutor() as executor:
#      38         futures = []
#      40         for i in range(self.trial):
#
# File ~\anaconda3\envs\mtdsimdebugtest\Lib\concurrent\futures\_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File ~\anaconda3\envs\mtdsimdebugtest\Lib\concurrent\futures\process.py:851, in ProcessPoolExecutor.shutdown(self, wait, cancel_futures)
#     848         self._executor_manager_thread_wakeup.wakeup()
#     850 if self._executor_manager_thread is not None and wait:
# --> 851     self._executor_manager_thread.join()
#     852 # To reduce the risk of opening too many files, remove references to
#     853 # objects that use file descriptors.
#     854 self._executor_manager_thread = None
#
# File ~\anaconda3\envs\mtdsimdebugtest\Lib\threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~\anaconda3\envs\mtdsimdebugtest\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

gamma_vals = [0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.98, 0.99]
ids_sensitivity = [1]
epsilons = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
epsilon_decays = [0.980, 0.990, 0.995, 0.998]

for gamma in gamma_vals:
    mod = f"DOWNTIMETESTgamma_{gamma}"
    print(f"Running experiments for model {mod}")
    result = Experiment(epsilon=epsilon, 
                    start_time=start_time, 
                    finish_time=finish_time, 
                    mtd_interval=mtd_interval, 
                    network_size=network_size,
                    total_nodes=total_nodes, 
                    new_network=new_network, 
                    model=mod, 
                    trial=trial, 
                    result_head_path=result_head_path, 
                    file_name=mod, 
                    attacker_sensitivity=1)
    result.run_trials('mtd_ai')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow as tf
#       2 tf.config.set_visible_devices([], 'GPU')
#       4 gamma_vals = [0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.98, 0.99]
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\__init__.py:47
#      44 from tensorflow.python import tf2 as _tf2
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#      49 from tensorflow._api.v2 import audio
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
#       9 from tensorflow._api.v2.__internal__ import decorator
#      10 from tensorflow._api.v2.__internal__ import dispatch
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.autograph namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx # line: 34
#       9 from tensorflow.python.autograph.impl.api import tf_convert # line: 493
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\python\autograph\utils\context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\tensorflow\python\framework\ops.py:29
#      26 from typing import cast, TypeVar, Any, AnyStr, NoReturn, Optional, Pattern, Union, ContextManager
#      28 from absl import app
# ---> 29 import numpy as np
#      30 from numpy import typing as npt
#      32 from google.protobuf import message
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\__init__.py:223
#     221 from .core import round, abs, max, min
#     222 # now that numpy modules are imported, can initialize limits
# --> 223 core.getlimits._register_known_types()
#     225 __all__.extend(['__version__', 'show_config'])
#     226 __all__.extend(core.__all__)
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\getlimits.py:226, in _register_known_types()
#     224 with numeric.errstate(all='ignore'):
#     225     huge_f128 = (ld(1) - epsneg_f128) / tiny_f128 * ld(4)
# --> 226 float128_ma = MachArLike(ld,
#     227                          machep=-112,
#     228                          negep=-113,
#     229                          minexp=-16382,
#     230                          maxexp=16384,
#     231                          it=112,
#     232                          iexp=15,
#     233                          ibeta=2,
#     234                          irnd=5,
#     235                          ngrd=0,
#     236                          eps=exp2(ld(-112)),
#     237                          epsneg=epsneg_f128,
#     238                          huge=huge_f128,
#     239                          tiny=tiny_f128)
#     240 # IEEE 754 128-bit binary float
#     241 _register_type(float128_ma,
#     242     b'\x9a\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\x99\xfb\xbf')
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\getlimits.py:55, in MachArLike.__init__(self, ftype, eps, epsneg, huge, tiny, ibeta, smallest_subnormal, **kwargs)
#      52 self.precision = int(-log10(self.eps))
#      53 self.resolution = self._float_to_float(
#      54     self._float_conv(10) ** (-self.precision))
# ---> 55 self._str_eps = self._float_to_str(self.eps)
#      56 self._str_epsneg = self._float_to_str(self.epsneg)
#      57 self._str_xmin = self._float_to_str(self.xmin)
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\getlimits.py:119, in MachArLike._float_to_str(self, value)
#     111 def _float_to_str(self, value):
#     112     """Converts float to str.
#     113
#     114     Parameters
#    (...)
#     117         value to be converted.
#     118     """
# --> 119     return self.params['fmt'] % array(_fr0(value)[0], self.ftype)
#
# File ~\anaconda3\envs\mtdsimMOO\Lib\site-packages\numpy\core\arrayprint.py:1586, in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1579 # the str of 0d arrays is a special case: It should appear like a scalar,
#    1580 # so floats are not truncated by `precision`, and strings are not wrapped
#    1581 # in quotes. So we return the str of the scalar value.
#    1582 if a.shape == ():
#    1583     # obtain a scalar and call str on it, avoiding problems for subclasses
#    1584     # for which indexing with () returns a 0d instead of a scalar by using
#    1585     # ndarray's getindex. Also guard against recursive 0d object arrays.
# -> 1586     return _guarded_repr_or_str(np.ndarray.__getitem__(a, ()))
#    1588 return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#
# AttributeError: module 'numpy' has no attribute 'ndarray'

# %%
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

epsilons = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
epsilon_decays = [0.980, 0.990, 0.995, 0.998]

for epsilon in epsilons:
    for decay in epsilon_decays:
        mod = f"epsilon_{epsilon}_decay_{decay}"
        print(f"Running experiments for model {mod}")
        result = Experiment(epsilon=epsilon, 
                        start_time=start_time, 
                        finish_time=finish_time, 
                        mtd_interval=mtd_interval, 
                        network_size=network_size,
                        total_nodes=total_nodes, 
                        new_network=new_network, 
                        model=mod, 
                        trial=trial, 
                        result_head_path=result_head_path, 
                        file_name=mod, 
                        attacker_sensitivity=1)
        result.run_trials('mtd_ai')

# %%
train_starts = [500, 1000, 1500, 2000]
ids_sensitivity = [1]
tf.config.set_visible_devices([], 'GPU')

for start in train_starts:
    mod = f"train_start_{start}"
    print(f"Running experiments for model {mod}")
    result = Experiment(epsilon=epsilon, 
                    start_time=start_time, 
                    finish_time=finish_time, 
                    mtd_interval=mtd_interval, 
                    network_size=network_size,
                    total_nodes=total_nodes, 
                    new_network=new_network, 
                    model=mod, 
                    trial=trial, 
                    result_head_path=result_head_path, 
                    file_name=mod, 
                    attacker_sensitivity=1)
    result.run_trials('mtd_ai')

# %%
models = ['parameter_set_1']
ids_sensitivity = [0.25]

for model in models:
    for sensitivity in ids_sensitivity:
        file_name = f"{model}_{sensitivity}"
        print(f"Running experiments for model {model}")
        result = Experiment(epsilon=epsilon, 
                            start_time=start_time, 
                            finish_time=finish_time, 
                            mtd_interval=mtd_interval, 
                            network_size=network_size,
                            total_nodes=total_nodes, 
                            new_network=new_network, 
                            model=model, 
                            trial=trial, 
                            result_head_path=result_head_path, 
                            file_name=file_name, 
                            attacker_sensitivity=sensitivity)
        result.run_trials('mtd_ai')

# %%
models = ['nomtd']
# models = ['parameter_set_1']
ids_sensitivity = [1]

for model in models:
    for sensitivity in ids_sensitivity:
        file_name = f"{model}_{sensitivity}"
        print(f"Running experiments for model {model}")
        result = Experiment(epsilon=epsilon, 
                            start_time=start_time, 
                            finish_time=finish_time, 
                            mtd_interval=mtd_interval, 
                            network_size=network_size,
                            total_nodes=total_nodes, 
                            new_network=new_network, 
                            model=model, 
                            trial=trial, 
                            result_head_path=result_head_path, 
                            file_name=file_name, 
                            attacker_sensitivity=sensitivity)
        result.run_trials('nomtd')

# %%
# models = ['parameter_set_1', 'parameter_set_2', 'parameter_set_3', 'parameter_set_4', 'parameter_set_5', 'parameter_set_6', 'parameter_set_7', 'parameter_set_8', 'parameter_set_9', 'parameter_set_10']
models = ['parameter_set_8']
ids_sensitivity = [0.25, 0.75]

for model in models:
    for sensitivity in ids_sensitivity:
        file_name = f"{model}_{sensitivity}"
        print(f"Running experiments for model {model}")
        result = Experiment(epsilon=epsilon, 
                            start_time=start_time, 
                            finish_time=finish_time, 
                            mtd_interval=mtd_interval, 
                            network_size=network_size,
                            total_nodes=total_nodes, 
                            new_network=new_network, 
                            model=model, 
                            trial=trial, 
                            result_head_path=result_head_path, 
                            file_name=file_name, 
                            attacker_sensitivity=sensitivity)
        result.run_trials('mtd_ai')

# %%
models = ['alternative']
# models = ['parameter_set_1']
ids_sensitivity = [1]

for model in models:
    for sensitivity in ids_sensitivity:
        file_name = f"{model}_{sensitivity}"
        print(f"Running experiments for model {model}")
        result = Experiment(epsilon=epsilon, 
                            start_time=start_time, 
                            finish_time=finish_time, 
                            mtd_interval=mtd_interval, 
                            network_size=network_size,
                            total_nodes=total_nodes, 
                            new_network=new_network, 
                            model=model, 
                            trial=trial, 
                            result_head_path=result_head_path, 
                            file_name=file_name, 
                            attacker_sensitivity=sensitivity)
        result.run_trials(model)

# %%
model = 'epsilon_0.5_decay_0.99'
gamma_vals = [0.5, 0.6, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 0.98, 0.99]
schemes = [f"gamma_{gamma}" for gamma in gamma_vals]

radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size, total_nodes, new_network, model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=schemes, data_name=schemes, run_trial=False, stats_type='median')
create_stacked_bar_chart(schemes_data, show_totals=True, length=8, sort_order='none')
# Out:
# C:\Users\Bubbakins\AppData\Local\Temp\ipykernel_29112\914033616.py:39: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   pastel_colors = cm.get_cmap('Pastel1', len(display_parameters))

# %%
model = 'epsilon_0.5_decay_0.995'

epsilons = [0.5, 0.6, 0.7, 0.8, 0.9, 1.0]
epsilon_decays = [0.980, 0.990, 0.995, 0.998]
schemes = [f"epsilon_{epsilon}_decay_{decay}" for epsilon in epsilons for decay in epsilon_decays]

radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size, total_nodes, new_network, model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=schemes, data_name=schemes, run_trial=False, stats_type='median')
create_stacked_bar_chart(schemes_data, show_totals=False, length=10, sort_order='desc')

# %%
model = 'gamma_0.5'
train_starts = [500, 1000, 1500, 2000]
schemes = [f"train_start_{start}" for start in train_starts]

radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size, total_nodes, new_network, model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=schemes, data_name=schemes, run_trial=False, stats_type='median')
create_stacked_bar_chart(schemes_data, show_totals=True, length=6, sort_order='desc')
# Out:
# C:\Users\Joo_Kai\AppData\Local\Temp\ipykernel_27616\914033616.py:39: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   pastel_colors = cm.get_cmap('Pastel1', len(display_parameters))

# %%
model = 'parameter_set_1'
radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network,  model, trial, result_head_path)
schemes_data = radar.scaled_pipeline(scheme='nomtd', data='nomtd', run_trial = False)
radar.plot_n_schemes(schemes_data)

# %%
create_stacked_bar_chart(schemes_data)

# %%
model = 'parameter_set_1'
radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network,  model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=['parameter_set_1_1', 'parameter_set_2_1', 'parameter_set_3_1', 'parameter_set_4_1', 'parameter_set_5_1', 'parameter_set_6_1', 'parameter_set_7_1', 'parameter_set_8_1', 'parameter_set_9_1', 'parameter_set_10_1'], data_name=['parameter_set_1_1', 'parameter_set_2_1', 'parameter_set_3_1', 'parameter_set_4_1', 'parameter_set_5_1', 'parameter_set_6_1', 'parameter_set_7_1', 'parameter_set_8_1', 'parameter_set_9_1', 'parameter_set_10_1'], run_trial = False)
radar.plot_n_schemes(schemes_data, show_labels=False)

# %%
create_stacked_bar_chart(schemes_data)

# %%
model = 'parameter_set_1'
radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network,  model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=['parameter_set_4_1', 'parameter_set_8_1'], data_name=['parameter_set_4_1', 'parameter_set_8_1', 'parameter_set_10_1'], run_trial = False)
radar.plot_n_schemes(schemes_data, show_labels=True)

# %%
schemes_data

# %%
model = 'parameter_set_8'
radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network,  model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=['parameter_set_8_0', 'parameter_set_8_0.25', 'parameter_set_8_0.5', 'parameter_set_8_0.75', 'parameter_set_8_1'], data_name=['parameter_set_8_0', 'parameter_set_8_0.25', 'parameter_set_8_0.5', 'parameter_set_8_0.75', 'parameter_set_8_1'], run_trial = False)
radar.plot_n_schemes(schemes_data, show_labels=False)

# %%
create_stacked_bar_chart(schemes_data)

# %%
model = 'parameter_set_8'
radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network,  model, trial, result_head_path)
schemes_data = radar.multiple_scaled_pipeline(schemes=['parameter_set_8_1', 'random', 'simultaneous'], data_name=['parameter_set_8_1', 'random', 'simultaneous'], run_trial = False)
radar.plot_n_schemes(schemes_data, show_labels=False)

# %%
create_stacked_bar_chart(schemes_data)

# %%
radar = RadarPlot(epsilon, start_time, finish_time, mtd_interval, network_size,total_nodes, new_network,  model, trial, result_head_path)
schemes_data = radar.scaled_pipeline(scheme='mtdai', data='parameter_set_8_1', run_trial = False)

data_sets = []
mods = ['parameter_set_1_1', 'parameter_set_2_1', 'parameter_set_3_1', 'parameter_set_4_1', 'parameter_set_5_1', 'parameter_set_6_1', 'parameter_set_7_1', 'parameter_set_8_1', 'parameter_set_9_1', 'parameter_set_10_1']
metrics = ['attack_path_exposure', 'time_to_compromise', 'ROA', 'ASR', 'risk']

for mod in mods:
    results = radar.scaled_pipeline(scheme='mtdai', data=mod, run_trial = False)
    data_sets.append(results)

# %%
plot_metrics_grid(data_sets, metrics)
